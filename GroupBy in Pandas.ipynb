# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv("googleplaystore.csv")

imputer = SimpleImputer(missing_values = np.NaN, strategy = "mean")
df.iloc[:, 2:3] = np.round(imputer.fit_transform(df.iloc[:, 2:3]), 2)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Q1 Name the apps in ART_AND_DESIGN with rating more than 4.5 in ascending order

# %%
df[(df["Category"] == "ART_AND_DESIGN") & (df["Rating"] >= 4.50)].sort_values(by=["Rating"])
# Out:
#                                                     App        Category  \
# 3                                 Sketch - Draw & Paint  ART_AND_DESIGN
# 17                             350 Diy Room Decor Ideas  ART_AND_DESIGN
# 41                         Sad Poetry Photo Frames 2018  ART_AND_DESIGN
# 32                            Anime Manga Coloring Book  ART_AND_DESIGN
# 13                                Mandala Coloring Book  ART_AND_DESIGN
# 19                                         ibis Paint X  ART_AND_DESIGN
# 46    Install images with music to make video withou...  ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 4764     X Launcher Prime: With OS Style Theme & No Ads  ART_AND_DESIGN
# 4755  X Launcher Pro: PhoneX Theme, OS11 Control Center  ART_AND_DESIGN
# 4749  X Launcher: With OS11 Style Theme & Control Ce...  ART_AND_DESIGN
# 45    Canva: Poster, banner, card maker & graphic de...  ART_AND_DESIGN
# ...

# %% [markdown]
# ## Q2 Name the apps in ART_AND_DESIGN in descending order WRT Ratings

# %%
df[df["Category"] == "ART_AND_DESIGN"].sort_values(by=["Rating"], ascending = False)
# Out:
#                                                     App        Category  \
# 8888            Spring flowers theme couleurs d t space  ART_AND_DESIGN
# 25                           Harley Quinn wallpapers HD  ART_AND_DESIGN
# 6930               Fantasy theme dark bw black building  ART_AND_DESIGN
# 5254                            AJ Styles HD Wallpapers  ART_AND_DESIGN
# 4759  X Launcher Pro - IOS Style Theme & Control Center  ART_AND_DESIGN
# ...                                                 ...             ...
# 6               Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN
# 35                     How to draw Ladybug and Cat Noir  ART_AND_DESIGN
# 43                                        Paint Splash!  ART_AND_DESIGN
# 5179                              Ai illustrator viewer  ART_AND_DESIGN
# 15                      Learn To Draw Kawaii Characters  ART_AND_DESIGN
#
#       Rating Reviews  Size  Installs  Type  Price Content Rating  \
# ...

# %% [markdown]
# ## Q3 Which Category is having Maximum Average Rating?

# %%
df.groupby(by=["Category"])["Rating"].mean().idxmax()
# Out:
# '1.9'

# %% [markdown]
# ## Q4 How many Free Apps are in each Category in Descending Order?

# %%
df[df["Type"] == "Free"].groupby(by=["Category"]).count()["Type"].sort_values(ascending=False)
# Out:
# Category
# FAMILY                 1780
# GAME                   1061
# TOOLS                   765
# BUSINESS                446
# PRODUCTIVITY            396
# LIFESTYLE               363
# SPORTS                  360
# COMMUNICATION           360
# MEDICAL                 354
# FINANCE                 349
# HEALTH_AND_FITNESS      325
# PHOTOGRAPHY             313
# PERSONALIZATION         309
# SOCIAL                  292
# NEWS_AND_MAGAZINES      281
# SHOPPING                258
# TRAVEL_AND_LOCAL        246
# DATING                  227
# BOOKS_AND_REFERENCE     203
# VIDEO_PLAYERS           171
# EDUCATION               152
# ENTERTAINMENT           147
# MAPS_AND_NAVIGATION     132
# FOOD_AND_DRINK          125
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       84
# AUTO_AND_VEHICLES        82
# WEATHER                  74
# EVENTS                   63
# ART_AND_DESIGN           62
# COMICS                   60
# PARENTING                58
# ...
